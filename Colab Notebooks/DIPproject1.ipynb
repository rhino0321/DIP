# %%
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt
import cv2
import numpy as np
def pixelVal(pix, r1,s1,r2,s2):
    if (0 <= pix and pix < r1):
        return (s1 / r1)*pix
    elif (r1 <= pix and pix < r2):
        return ((s2 - s1)/(r2 - r1)) * (pix - r1) + s1
    else:
        return ((255 - s2)/(255 - r2)) * (pix - r2) + s2
a=cv2.imread("/content/drive/MyDrive/DIP/fruit.tif",cv2.IMREAD_GRAYSCALE)
s1=0
s2=255
img2=cv2.GaussianBlur(a,(3,3),0)
r1=np.amin(img2)
r2=np.amax(img2)
pixelVal_vec=np.vectorize(pixelVal)
img3=pixelVal_vec(img2,r1,s1,r2,s2)
cv2_imshow(img3)
plt.hist(a.ravel(),np.arange(0,255))
plt.show()

# %%
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt
import cv2
import numpy as np
def pixelVal(pix, r1,s1,r2,s2):
    if (0 <= pix and pix < r1):
        return (s1 / r1)*pix
    elif (r1 <= pix and pix < r2):
        return ((s2 - s1)/(r2 - r1)) * (pix - r1) + s1
    else:
        return ((255 - s2)/(255 - r2)) * (pix - r2) + s2
img1=cv2.imread("/content/drive/MyDrive/DIP/fruit-a.png",cv2.IMREAD_GRAYSCALE)
img2=cv2.GaussianBlur(img1,(3,3),0);
Laplacian_img=cv2.Laplacian(img2,cv2.CV_8U,3)
b=cv2.convertScaleAbs(Laplacian_img)
s1=0
s2=255
r1=np.amin(b)
r2=np.amax(b)
pixelVal_vec=np.vectorize(pixelVal)
img3=pixelVal_vec(b,r1,s1,r2,s2)
cv2_imshow(img3)
plt.imshow(img3,cmap=plt.get_cmap('gray'))
plt.savefig('/content/drive/MyDrive/DIPans/fruit-b.png',dpi =200)

# %%
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt
import cv2;
import numpy as np
def pixelVal(pix, r1,s1,r2,s2):
    if (0 <= pix and pix < r1):
        return (s1 / r1)*pix
    elif (r1 <= pix and pix < r2):
        return ((s2 - s1)/(r2 - r1)) * (pix - r1) + s1
    else:
        return ((255 - s2)/(255 - r2)) * (pix - r2) + s2
img1=cv2.imread("/content/drive/MyDrive/DIP/fruit-a.png",cv2.IMREAD_GRAYSCALE)
img2=cv2.GaussianBlur(img1,(3,3),0);
Gx=cv2.Sobel(img2,cv2.CV_8U,1,0)
Gy=cv2.Sobel(img2,cv2.CV_8U,0,1)
d=cv2.add(Gx,Gy)
r1=np.amin(d)
r2=np.amax(d)
s1=0
s2=255  
pixelVal_vec=np.vectorize(pixelVal)
img5=pixelVal_vec(d,r1,s1,r2,s2)
cv2_imshow(img5)
plt.imshow(img5,cmap=plt.get_cmap('gray'))
plt.savefig('/content/drive/MyDrive/DIPans/fruit-d.png',dpi =200)
# Out:
# (900, 900)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-48e43a2b4668> in <module>
#      21 s2=255
#      22 pixelVal_vec=np.vectorize(pixelVal)
# ---> 23 img5=pixelVal_vec(d,r1,s1,r2,s2)
#      24 cv2_imshow(img5)
#      25 plt.imshow(img5,cmap=plt.get_cmap('gray'))
#
# /usr/local/lib/python3.8/dist-packages/numpy/lib/function_base.py in __call__(self, *args, **kwargs)
#    2161             vargs.extend([kwargs[_n] for _n in names])
#    2162
# -> 2163         return self._vectorize_call(func=func, args=vargs)
#    2164
#    2165     def _get_ufunc_and_otypes(self, func, args):
#
# /usr/local/lib/python3.8/dist-packages/numpy/lib/function_base.py in _vectorize_call(self, func, args)
#    2244             inputs = [asanyarray(a, dtype=object) for a in args]
#    2245
# -> 2246             outputs = ufunc(*inputs)
#    2247
# ...

# %%
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt
import cv2
import numpy as np
def pixelVal(pix, r1,s1,r2,s2):
    if (0 <= pix and pix < r1):
        return (s1 / r1)*pix
    elif (r1 <= pix and pix < r2):
        return ((s2 - s1)/(r2 - r1)) * (pix - r1) + s1
    else:
        return ((255 - s2)/(255 - r2)) * (pix - r2) + s2
img1 = cv2.imread('/content/drive/MyDrive/DIP/fruit-a.png',cv2.IMREAD_GRAYSCALE)
img2 = cv2.imread('/content/drive/MyDrive/DIP/fruit-b.png',cv2.IMREAD_GRAYSCALE)
img3=cv2.GaussianBlur(img1,(3,3),0);
img4=cv2.GaussianBlur(img2,(3,3),0);
c = cv2.add(img3,img4)
r1=np.amin(c)
r2=np.amax(c)
s1=0
s2=255  
pixelVal_vec=np.vectorize(pixelVal)
img5=pixelVal_vec(c,r1,s1,r2,s2)
cv2_imshow(img5)
plt.imshow(img5,cmap=plt.get_cmap('gray'))
plt.savefig('/content/drive/MyDrive/DIPans/fruit-c.png',dpi =200)

# %%
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt
import cv2;
import numpy as np
def pixelVal(pix, r1,s1,r2,s2):
    if (0 <= pix and pix < r1):
        return (s1 / r1)*pix
    elif (r1 <= pix and pix < r2):
        return ((s2 - s1)/(r2 - r1)) * (pix - r1) + s1
    else:
        return ((255 - s2)/(255 - r2)) * (pix - r2) + s2
img1=cv2.imread("/content/drive/MyDrive/DIP/fruit-d.png",cv2.IMREAD_GRAYSCALE)
img2=cv2.GaussianBlur(img1,(3,3),0)
e=cv2.blur(img2,(5,5))
r1=np.amin(e)
r2=np.amax(e)
s1=0
s2=255  
pixelVal_vec=np.vectorize(pixelVal)
img5=pixelVal_vec(e,r1,s1,r2,s2)
cv2_imshow(img5)
plt.imshow(img5,cmap=plt.get_cmap('gray'))
plt.savefig('/content/drive/MyDrive/DIPans/fruit-e.png',dpi =200)

# %%
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt
import cv2;
import numpy as np
def pixelVal(pix, r1,s1,r2,s2):
    if (0 <= pix and pix < r1):
        return (s1 / r1)*pix
    elif (r1 <= pix and pix < r2):
        return ((s2 - s1)/(r2 - r1)) * (pix - r1) + s1
    else:
        return ((255 - s2)/(255 - r2)) * (pix - r2) + s2
img1=cv2.imread("/content/drive/MyDrive/DIP/fruit-b.png",cv2.IMREAD_GRAYSCALE)
img2=cv2.imread("/content/drive/MyDrive/DIP/fruit-e.png",cv2.IMREAD_GRAYSCALE)
img3=cv2.GaussianBlur(img1,(3,3),0);
img4=cv2.GaussianBlur(img2,(3,3),0);
f=cv2.multiply(img3,img4,cv2.CV_8U)
r1=np.amin(f)
r2=np.amax(f)
s1=0
s2=255  
pixelVal_vec=np.vectorize(pixelVal)
img5=pixelVal_vec(f,r1,s1,r2,s2)
cv2_imshow(img5)
plt.imshow(img5,cmap=plt.get_cmap('gray'))
plt.savefig('/content/drive/MyDrive/DIPans/fruit-f.png',dpi =200)

# %%
from google.colab.patches import cv2_imshow
import cv2
import numpy as np
import matplotlib.pyplot as plt
def pixelVal(pix, r1,s1,r2,s2):
    if (0 <= pix and pix < r1):
        return (s1 / r1)*pix
    elif (r1 <= pix and pix < r2):
        return ((s2 - s1)/(r2 - r1)) * (pix - r1) + s1
    else:
        return ((255 - s2)/(255 - r2)) * (pix - r2) + s2
img1 = cv2.imread('/content/drive/MyDrive/DIP/fruit-a.png',cv2.IMREAD_GRAYSCALE)
img2 = cv2.imread('/content/drive/MyDrive/DIP/fruit-f.png',cv2.IMREAD_GRAYSCALE)
img3=cv2.GaussianBlur(img1,(3,3),0);
img4=cv2.GaussianBlur(img2,(3,3),0);
g = cv2.add(img3,img4)  
r1=np.amin(g)
r2=np.amax(g)
s1=0
s2=255  
pixelVal_vec=np.vectorize(pixelVal)
img5=pixelVal_vec(g,r1,s1,r2,s2)
cv2_imshow(img5)
plt.imshow(img5,cmap=plt.get_cmap('gray'))
plt.savefig('/content/drive/MyDrive/DIPans/fruit-g.png',dpi =200)

# %%
from google.colab.patches import cv2_imshow
import numpy as np
import cv2
import matplotlib.pyplot as plt
def pixelVal(pix, r1,s1,r2,s2):
    if (0 <= pix and pix < r1):
        return (s1 / r1)*pix
    elif (r1 <= pix and pix < r2):
        return ((s2 - s1)/(r2 - r1)) * (pix - r1) + s1
    else:
        return ((255 - s2)/(255 - r2)) * (pix - r2) + s2
img1=cv2.imread('/content/drive/MyDrive/DIP/fruit-g.png',cv2.IMREAD_GRAYSCALE)
img2=cv2.GaussianBlur(img1,(3,3),0);
h = np.array(255*(img2 / 255) ** 0.5, dtype = 'uint8') 
s1=0
s2=255 
r1=np.amin(h)
r2=np.amax(h)  
pixelVal_vec=np.vectorize(pixelVal)
img3=pixelVal_vec(h,r1,s1,r2,s2)
cv2_imshow(img3)
plt.hist(img3.ravel(),np.arange(0,255))
plt.show()
